# %%
from env import *
from calculate import *

# %%
# 设置不同的规模比例
min_scale = 5
middle_scale = 10
max_scale = 20

# %%
"""
运行 GMP-DRL 优化
"""
from model.dqn import train_dqn
model = train_dqn(min_scale)
log_n()
# Out:
# Episode 0 | Total Reward: 0.10 | Total Fitness: 0.20         | Total Distance: 1084.29 | Total Time: 1284.51         | Total Success : 0.13 | Epsilon: 0.995
# Episode 1 | Total Reward: 0.13 | Total Fitness: 0.39         | Total Distance: 1047.95 | Total Time: 1235.51         | Total Success : 0.20 | Epsilon: 0.990
# Episode 2 | Total Reward: 0.04 | Total Fitness: 0.26         | Total Distance: 1022.05 | Total Time: 994.95         | Total Success : 0.07 | Epsilon: 0.985
# Episode 3 | Total Reward: 0.18 | Total Fitness: 0.32         | Total Distance: 1086.63 | Total Time: 1040.95         | Total Success : 0.27 | Epsilon: 0.980
# Episode 4 | Total Reward: 0.00 | Total Fitness: 0.26         | Total Distance: 1197.99 | Total Time: 1089.08         | Total Success : 0.00 | Epsilon: 0.975
# Episode 5 | Total Reward: 0.12 | Total Fitness: 0.33         | Total Distance: 1045.76 | Total Time: 1128.18         | Total Success : 0.20 | Epsilon: 0.970
# ...
