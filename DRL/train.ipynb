# %%
from env import *
from calculate import *

# %%
# 设置不同的规模比例
min_scale = 5
middle_scale = 10
max_scale = 20

# %%
"""
运行 GMP-DRL 优化
"""
from model.dqn import train_dqn
model = train_dqn(max_scale)
log_n()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       1 """
#       2 运行 GMP-DRL 优化
#       3 """
#       4 from model.dqn import train_dqn
# ----> 5 model = train_dqn(max_scale)
#       6 log_n()
#
# File d:\code\python_project\mywork\DRL\model\dqn.py:195, in train_dqn(scale, episodes, batch_size, gamma, lr, eps_start, eps_end, eps_decay, save_dir)
#     193 q_pred = policy_net(s).gather(1, a.unsqueeze(1)).squeeze()
#     194 with torch.no_grad():
# --> 195     best_actions = policy_net(s2).argmax(1)
#     196     q_next = (
#     197         target_net(s2).gather(1, best_actions.unsqueeze(1)).squeeze()
#     198     )
#     199 q_target = r + gamma * q_next * (1 - d)
#
# File d:\develop\anaconda\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
# ...
