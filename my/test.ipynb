# %%
from env import *
from calculate import *
from runEnv import UAVEnv
import time
from datetime import datetime

# %%
# 调度算法
from model.random import random_allocation
from model.rr import round_robin_allocation
from model.ga import GeneticAlgorithmScheduler
from model.pso import PSO
from model.hs_mopso import HS_MOPSO
from model.dqn import test_dqn
from model.dqn import test_dqn

# %%
test_uav_csv = "data/test/uav.csv"
test_task_csv = "data/test/task.csv"

# %%
# 测试负载均衡
t_uavs, t_tasks, t_targets = load_different_scale_csv(test_uav_csv, test_task_csv, 10)
env = UAVEnv(t_uavs, t_targets, t_tasks)

# MOPSO
mopso = HS_MOPSO(env)
mopso.run()

# GMP_DRL
# test_dqn(env, 10)
# Out:
# Iter 1, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2397.80 | Total Time: 1463.24 | Total Success : 0.77
# Iter 2, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2400.28 | Total Time: 1536.54 | Total Success : 0.77
# Iter 3, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2416.56 | Total Time: 1567.53 | Total Success : 0.77
# Iter 4, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2339.63 | Total Time: 1447.75 | Total Success : 0.77
# Iter 5, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2471.94 | Total Time: 1688.57 | Total Success : 0.77
# Iter 6, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2400.28 | Total Time: 1536.54 | Total Success : 0.77
# Iter 7, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2356.03 | Total Time: 1514.86 | Total Success : 0.77
# Iter 8, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2400.28 | Total Time: 1536.54 | Total Success : 0.77
# Iter 9, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2383.36 | Total Time: 1536.54 | Total Success : 0.77
# Iter 10, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2418.92 | Total Time: 1521.20 | Total Success : 0.77
# Iter 11, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2331.30 | Total Time: 1510.92 | Total Success : 0.77
# Iter 12, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2435.80 | Total Time: 1549.12 | Total Success : 0.77
# Iter 13, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2365.57 | Total Time: 1506.41 | Total Success : 0.77
# Iter 14, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2400.28 | Total Time: 1536.54 | Total Success : 0.77
# Iter 15, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2400.28 | Total Time: 1536.54 | Total Success : 0.77
# Iter 16, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2338.91 | Total Time: 1362.64 | Total Success : 0.77
# Iter 17, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2400.28 | Total Time: 1536.54 | Total Success : 0.77
# Iter 18, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2339.67 | Total Time: 1380.75 | Total Success : 0.77
# Iter 19, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2356.03 | Total Time: 1514.86 | Total Success : 0.77
# Iter 20, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2400.28 | Total Time: 1536.54 | Total Success : 0.77
# Iter 21, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2400.28 | Total Time: 1536.54 | Total Success : 0.77
# Iter 22, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2443.34 | Total Time: 1570.15 | Total Success : 0.77
# Iter 23, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2363.20 | Total Time: 1508.58 | Total Success : 0.77
# Iter 24, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2424.55 | Total Time: 1607.40 | Total Success : 0.77
# Iter 25, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2372.59 | Total Time: 1539.90 | Total Success : 0.77
# Iter 26, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2400.28 | Total Time: 1536.54 | Total Success : 0.77
# Iter 27, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2331.21 | Total Time: 1453.12 | Total Success : 0.77
# Iter 28, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2435.80 | Total Time: 1549.12 | Total Success : 0.77
# Iter 29, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2457.09 | Total Time: 1528.76 | Total Success : 0.77
# Iter 30, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2493.78 | Total Time: 1659.62 | Total Success : 0.77
# Iter 31, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2400.28 | Total Time: 1536.54 | Total Success : 0.77
# Iter 32, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2383.44 | Total Time: 1555.82 | Total Success : 0.77
# Iter 33, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2400.28 | Total Time: 1536.54 | Total Success : 0.77
# Iter 34, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2365.59 | Total Time: 1513.41 | Total Success : 0.77
# Iter 35, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2445.56 | Total Time: 1524.92 | Total Success : 0.77
# Iter 36, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2383.36 | Total Time: 1536.54 | Total Success : 0.77
# Iter 37, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2339.99 | Total Time: 1476.41 | Total Success : 0.77
# Iter 38, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2400.28 | Total Time: 1536.54 | Total Success : 0.77
# Iter 39, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2331.30 | Total Time: 1510.92 | Total Success : 0.77
# Iter 40, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2404.00 | Total Time: 1550.72 | Total Success : 0.77
# Iter 41, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2339.67 | Total Time: 1380.75 | Total Success : 0.77
# Iter 42, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2390.00 | Total Time: 1544.80 | Total Success : 0.77
# Iter 43, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2400.28 | Total Time: 1536.54 | Total Success : 0.77
# Iter 44, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2402.55 | Total Time: 1539.22 | Total Success : 0.77
# Iter 45, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2369.75 | Total Time: 1536.88 | Total Success : 0.77
# Iter 46, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2493.78 | Total Time: 1659.62 | Total Success : 0.77
# Iter 47, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2400.28 | Total Time: 1536.54 | Total Success : 0.77
# Iter 48, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2378.54 | Total Time: 1518.43 | Total Success : 0.77
# Iter 49, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2399.31 | Total Time: 1548.70 | Total Success : 0.77
# [('UAV11', 'TASK11'), ('UAV02', 'TASK01'), ('UAV22', 'TASK21'), ('UAV11', 'TASK12'), ('UAV02', 'TASK02'), ('UAV21', 'TASK22'), ('UAV12', 'TASK13'), ('UAV02', 'TASK03'), ('UAV22', 'TASK23'), ('UAV13', 'TASK14'), ('UAV03', 'TASK04'), ('UAV22', 'TASK24'), ('UAV13', 'TASK15'), ('UAV04', 'TASK05'), ('UAV23', 'TASK25'), ('UAV13', 'TASK16'), ('UAV03', 'TASK06'), ('UAV23', 'TASK26'), ('UAV12', 'TASK17'), ('UAV04', 'TASK07'), ('UAV01', 'TASK27'), ('UAV03', 'TASK18'), ('UAV12', 'TASK08'), ('UAV21', 'TASK28'), ('UAV11', 'TASK19'), ('UAV22', 'TASK09'), ('UAV12', 'TASK29'), ('UAV13', 'TASK20'), ('UAV01', 'TASK10'), ('UAV23', 'TASK30')]
# Iter 50, Total Reward: 0.67 | Total Fitness: 0.80 | Total Distance: 2400.28 | Total Time: 1536.54 | Total Success : 0.77

# %%
# for scale in [5, 10,20]:
#     # 加载不同规模的无人机、任务和目标数据
#     t_uavs, t_tasks, t_targets = load_different_scale_csv(test_uav_csv, test_task_csv, scale)
#     env = UAVEnv(t_uavs, t_targets, t_tasks)

#     # 运行随机算法
#     start_time = time.time()
#     random_allocation(env)
#     elapsed = time.time() - start_time
#     log_time(elapsed)

#     # 运行 RR 轮询算法
#     start_time = time.time()
#     round_robin_allocation(env)
#     elapsed = time.time() - start_time
#     log_time(elapsed)

#     # GA
#     start_time = time.time()
#     ga_scheduler = GeneticAlgorithmScheduler(env)
#     ga_scheduler.run()
#     elapsed = time.time() - start_time
#     log_time(elapsed)

#     # PSO
#     start_time = time.time()
#     pso = PSO(env)
#     pso.optimize()
#     elapsed = time.time() - start_time
#     log_time(elapsed)
    
#     # MOPSO
#     start_time = time.time()
#     mopso = HS_MOPSO(env)
#     mopso.run()
#     elapsed = time.time() - start_time
#     log_time(elapsed)

#     # GMP_DRL
#     start_time = time.time()
#     test_dqn(env, scale)
#     elapsed = time.time() - start_time
#     log_time(elapsed)

#     log_n()
